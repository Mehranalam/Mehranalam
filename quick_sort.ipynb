# %%
def partition(arr, low, high):
    pviot = arr[high]
    i = low - 1

    print(arr)
    print("------1")
    for j in range(low, high):
        print(arr)
        print("------2")
        if arr[j] <= pviot:
            i = i + 1

            (arr[j] ,arr[i]) = (arr[i] ,arr[j])
            print(arr)
            print("------3")

   
    (arr[i+1] ,arr[high]) = (arr[high] ,arr[i+1])
    print(arr)
    print("------4")
    return i + 1

def qs(arr, low, high):
    print(arr)
    print("------5")
    if low <= high:
        print(f"low = {low}@")
        pi = partition(arr, low, high)
        print(f"pi is {pi}#")
        qs(arr, low, pi - 1) # 1-1 = 0, high 0
        print(arr)
        print("------6")
        qs(arr, pi + 1 ,high)
        print(arr)
        print("------7")
    return arr



l = [3,7,8,9,1,4,5,2]

# %% [markdown]
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------5
# low = 0@
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------1
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------2
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------2
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------2
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------2
# [3, 7, 8, 9, 1, 4, 5, 2]
# ------2
# [1, 7, 8, 9, 3, 4, 5, 2]
# ------3
# [1, 7, 8, 9, 3, 4, 5, 2]
# ------2
# [1, 7, 8, 9, 3, 4, 5, 2]
# ------2
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------4
# pi is 1#
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------5
# low = 0@
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------1
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------4
# pi is 0#
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------5
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------6
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------5
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------7
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------6
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------5
# low = 2@
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------1
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------2
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------2
# [1, 2, 8, 9, 3, 4, 5, 7]
# ------2
# [1, 2, 3, 9, 8, 4, 5, 7]
# ------3
# [1, 2, 3, 9, 8, 4, 5, 7]
# ------2
# [1, 2, 3, 4, 8, 9, 5, 7]
# ------3
# [1, 2, 3, 4, 8, 9, 5, 7]
# ------2
# [1, 2, 3, 4, 5, 9, 8, 7]
# ------3
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------4
# pi is 5#
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# low = 2@
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------1
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------2
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------3
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------2
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------3
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------4
# pi is 4#
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# low = 2@
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------1
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------2
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------3
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------4
# pi is 3#
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# low = 2@
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------1
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------4
# pi is 2#
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------6
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------6
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------6
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------6
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# low = 6@
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------1
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------2
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------3
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------4
# pi is 7#
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# low = 6@
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------1
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------4
# pi is 6#
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------6
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------6
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------5
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
# [1, 2, 3, 4, 5, 7, 8, 9]
# ------7
#
# [1, 2, 3, 4, 5, 7, 8, 9]
